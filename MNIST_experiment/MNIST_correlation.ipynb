# %%
import numpy as np
import torchvision.datasets as datasets
import torchvision.transforms as transforms
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Define the transformation to apply to the data
transform = transforms.Compose([transforms.ToTensor()])

# Load the MNIST dataset
trainset = datasets.MNIST(root='./data', train=True, download=True, transform=transform)
testset = datasets.MNIST(root='./data', train=False, download=True, transform=transform)

# Convert the data to NumPy arrays
train_data = trainset.data.numpy() / 255.0
train_data = np.reshape(train_data, (train_data.shape[0], -1))
train_labels = trainset.targets.numpy()
test_data = testset.data.numpy() / 255.0
test_labels = testset.targets.numpy()

# %%
train_labels[:10]
# Out:
# array([5, 0, 4, 1, 9, 2, 1, 3, 1, 4])

# %%
train_data.max()
# Out:
# 1.0

# %%
big_corr = np.zeros((60000, 784, 784))
for i in range(60000):
    big_corr[i] = np.outer(train_data[i], train_data[i])
    if i % 1000 == 0:
        print(i)
# Out:
# 0
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# 33000
# 34000
# 35000
# 36000
# 37000
# 38000
# 39000
# 40000
# 41000
# 42000
# 43000
# 44000
# 45000
# 46000
# 47000
# 48000
# 49000
# 50000
# 51000
# 52000
# 53000
# 54000
# 55000
# 56000
# 57000
# 58000
# 59000

# %%
corr = np.outer(train_data[0], train_data[0])
corr.shape
# Out:
# (784, 784)

# %%
plt.figure()
sns.heatmap(corr)
plt.show()
