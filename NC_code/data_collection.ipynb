# %%
import torch
import argparse
import json
import torch.nn as nn
import torch.nn.functional as F
from torch.nn.parameter import Parameter
from torch.utils.data import Dataset, DataLoader, random_split
import math
import json
import numpy as np
import matplotlib.pyplot as plt
import torch.optim as optim
import pickle
import time
from scipy.optimize import minimize
import geatpy as ea

# %%
# data_pas = np.load('/data/mjy/Yeqiang/subthres_coarse_data.npz')
data_fire = np.load('/data/mjy/Yeqiang/coarse_fire_data.npz')

# %%
data_fire.keys()
# Out:
# KeysView(NpzFile '/data/mjy/Yeqiang/coarse_fire_data.npz' with keys: coarse_v_array, coarse_ip_m_array)

# %%
# X = data_pas['coarse_ip_m_array']
# Y = data_pas['coarse_v_array']  
X = data_fire['coarse_ip_m_array']
Y = data_fire['coarse_v_array']

# %%
X.shape, Y.shape
# Out:
# ((1200, 9, 5001), (1200, 5001))

# %%
plt.plot(Y[300])
